# %%
fruits_dic = {"apple": 6000, "melon": 3000, "banana": 5000, "Orange": 4000 }
print("dict_Keys",list(fruits_dic))
if fruits_dic.get("apple") is not None:
    print("{} is in fruit_dic".format(*["apple"]))
else:
     print("{} is not in fruit_dic".format(*["apple"]))
if fruits_dic.get("mango") is not None:
    print("{} is in fruit_dic".format(*["mango"]))
else:
    print("{} is not in fruit_dic".format(*["mango"]))
# Out:
# dict_Keys ['apple', 'melon', 'banana', 'Orange']
# apple is in fruit_dic
# mango is not in fruit_dic
